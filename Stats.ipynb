# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishnakant-Pal/iNeuron-DS-Assessment/blob/main/Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.What is the Meaning of the Six Sigma in statistics? Give proper example?

# %% [markdown]
# The term "Six Sigma" refers to a level of quality that allows only 3.4 defects per million opportunities (DPMO). Its a statistic methodology to identify the errors in business process and eliminate them.

# %% [markdown]
# **2.What type of data does not have a log-normal distribution or a Gaussian distribution?  Give proper example**

# %% [markdown]
# Data which does not have log-normal distribution or a Gaussian distribution have skewness, heavy tails or multimodal data. This type of data doesn’t have bell curve distribution.
#
# Example:
# We can take an example as a wealth distribution in any country, countries with a majority of population have low to average incomes whereas some individuals have very high amount of wealth. This type of data has a heavy tail.

# %% [markdown]
# **3.What is the meaning of the five-number summary in Statistics? Give proper example**

# %% [markdown]
# Five number summary is very useful to analyse the distribution of the data. It contains only five numbers; these are Minimum,First Quartile(Q1),Median (Q2,Third Quartile (Q3) and Maximum.
# Minimum: It shows the smallest value of the dataset.
# First Quartile(q1): It shows the first 25% of the data.
# Median: it shows 0 -50% of the data.
# Third Quartile(q3): It show the 0-75% of the data
# This number can be visualised easily with a box and whiskers plot.

# %% [markdown]
# **4.What is correlation? Give an example with a dataset & graphical representation on jupyter Notebook**

# %% [markdown]
# Correlation is the relationship between two variable one affecting other variable.
#
# There is 2 types of correlations:
# 1. Positive correlation : If one variable increases, the other variable also increases linearly then there is positive correlation.
# 2. Negative correlation : If one variable increases, the other variable decreases linearly then there is negative correlation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


data = {
    'Hours Studied': [2, 3, 4, 5, 6, 7, 8, 9, 10],
    'Test Score': [40, 50, 60, 65, 70, 75, 80, 85, 90]
}

df = pd.DataFrame(data)

# correlation matrix
correlation_matrix = df.corr()

# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
